# %% [markdown]
# # SegFormer on KolektorSDD2
#
# Upload `segformer_ksdd2_colab.py` using the Colab file browser, or place it in your mounted Drive folder, then run the cells below.

# %%
# !pip install -q transformers accelerate torch torchvision pillow matplotlib tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Optional: inspect your uploaded dataset/archive before training.
# !ls -lah /content
# !file /content/KolektorSDD2.zip || true
# !find /content -maxdepth 3 -type d | sort | head -80

# %%
# Change these paths to match where your KSDD2 folder and script are in Colab.
DATA_ROOT = '/content/KolektorSDD2.zip'
OUTPUT_DIR = '/content/drive/MyDrive/segformer_ksdd2_runs'
SCRIPT_PATH = '/content/segformer_ksdd2_colab.py'

# %%
# !python "$SCRIPT_PATH" \
  --data-root "$DATA_ROOT" \
  --output-dir "$OUTPUT_DIR" \
  --epochs 20 \
  --batch-size 8 \
  --eval-batch-size 4
